# %% [markdown]
# # Preprocess data

# %% [markdown]
# ## import libraries
# Before running this, please install pyMAGIQ using setup.py.
# > python setup.py install

# %%
import numpy as np
import os
import csv 

# these are for avoiding PROJ_LIB error
# https://stackoverflow.com/questions/54201946/how-can-i-avoid-proj-lib-error-in-importing-basemap
import conda
conda_file_dir = conda.__file__
conda_dir = conda_file_dir.split('lib')[0]
proj_lib = os.path.join(os.path.join(conda_dir, 'share'), 'proj')
os.environ["PROJ_LIB"] = proj_lib

import pyMAGIQ
# Out:
# /Users/nimamura/.pyenv/versions/anaconda3-5.3.0/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:523: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /Users/nimamura/.pyenv/versions/anaconda3-5.3.0/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:524: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /Users/nimamura/.pyenv/versions/anaconda3-5.3.0/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:525: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /Users/nimamura/.pyenv/versions/anaconda3-5.3.0/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:526: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /Users/nimamura/.pyenv/versions/anaconda3-5.3.0/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:527: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /Users/nimamura/.pyenv/versions/anaconda3-5.3.0/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:532: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# Using TensorFlow backend.

# %% [markdown]
# ## Specify data information
# Raw files downloaded from:
# - http://ds.iris.edu/spud/emtf
#
# and saved training data in (datadir)/train, test data in (datadir)/test. Test data is used for the validation, so training and test data have to have rating information in xml file. Please save unrated data in (datadir)/unrated. Unrated data does not have rating information in xml file.

# %%
# frequency sets for USArray (Currently, this code works only with these frequencies)
freqsets = [  1.367187E-01, 1.093750E-01, 8.593753E-02, 6.640627E-02, 5.078124E-02, 3.906250E-02,
        3.027344E-02, 2.343750E-02, 1.855469E-02, 1.464844E-02, 1.171875E-02, 9.765625E-03,
        7.568361E-03, 5.859374E-03, 4.638671E-03, 3.662109E-03, 2.929688E-03, 2.441406E-03,
        1.892090E-03, 1.464844E-03, 1.159668E-03, 9.155271E-04, 7.324221E-04, 6.103516E-04,
        4.425049E-04, 3.204346E-04, 2.136230E-04, 1.373291E-04, 8.392331E-05, 5.340577E-05]

# number of frequency used in data
nfreq = len(freqsets)

datadir = '/Users/nimamura/Library/Mobile Documents/com~apple~CloudDocs/pyMAGIQ/pyMAGIQ/survey/USArray2019March'

traindir    = datadir + '/train'
X_trainpath = datadir + '/preprocessed/X_train.csv'
y_trainpath = datadir + '/preprocessed/y_train.csv'
rate_trainpath  = datadir + '/preprocessed/rate_train.csv'
SiteIDpath  = datadir + '/preprocessed/siteID_train.csv'
outputpath = datadir +'/outputs'

# list in training directory and test directory
trainlists = sorted( [f for f in os.listdir(traindir) if not f.startswith('.')] )

# number of lists
nMTtrain = len(trainlists)

# %% [markdown]
# ## Read training data
# * nrate : number of rating for impedance tensor
# * ndata : number of data used for impecance tensor (Apparent resistivities, phases and those errorbar)
# * ncomp : number of components used for impecance tensor (xy and yx)

# %%
nrate = 5
ndata = 4
ncomp = 2

# read X and y data from xml file
# read X_train and y_train
# X_train = np.zeros((nMTtrain,nfreq,ndata*ncomp*2),dtype=np.float32)    # Note that real value
# y_train = np.zeros((nMTtrain,),dtype=np.int)

# Make XML list from xml files
xml_train, SiteID_train = pyMAGIQ.utils.iofiles.io.get_XMLlists(nfreq,traindir,trainlists,freqsets)
# Out:
# MT_TF_USArray.ALW48.2015
# reading Z.INVSIGCOV
# MT_TF_USArray.ALW49.2015
# reading Z.INVSIGCOV
# MT_TF_USArray.ALX50.2015
# reading Z.INVSIGCOV
# MT_TF_USArray.ALY50.2015
# reading Z.INVSIGCOV
# MT_TF_USArray.ALZ51.2015
# reading Z.INVSIGCOV
# MT_TF_USArray.ARU43.2014
# Use Hx orientation as a declination angle, instead of original declination
# reading Z.INVSIGCOV
# MT_TF_USArray.CAM01.2007
# reading Z.INVSIGCOV
# MT_TF_USArray.CAM02.2010
# reading Z.INVSIGCOV
# MT_TF_USArray.CAM03.2010
# reading Z.INVSIGCOV
# MT_TF_USArray.CAM04.2010
# reading Z.INVSIGCOV
# MT_TF_USArray.CAM05.2010
# reading Z.INVSIGCOV
# MT_TF_USArray.CAM06.2010
# reading Z.INVSIGCOV
# MT_TF_USArray.CAM94.2010
# reading Z.INVSIGCOV
# MT_TF_USArray.CAN01.2010
# reading Z.INVSIGCOV
# MT_TF_USArray.CAN02.2010
# reading Z.INVSIGCOV
# MT_TF_USArray.CAN03.2010
# reading Z.INVSIGCOV
# MT_TF_USArray.CAN03.2011
# reading Z.INVSIGCOV
# MT_TF_USArray.CAN04.2010
# reading Z.INVSIGCOV
# MT_TF_USArray.CAN05.2010
# reading Z.INVSIGCOV
# MT_TF_USArray.CAN06.2010
# reading Z.INVSIGCOV
# MT_TF_USArray.CAO01.2010
# reading Z.INVSIGCOV
# MT_TF_USArray.CAO02.2010
# reading Z.INVSIGCOV
# MT_TF_USArray.CAO03.2010
# reading Z.INVSIGCOV
# MT_TF_USArray.CAO04.2010
# reading Z.INVSIGCOV
# MT_TF_USArray.CAO05.2010
# reading Z.INVSIGCOV
# MT_TF_USArray.CAO06.2010
# reading Z.INVSIGCOV
# MT_TF_USArray.CAP01.2010
# reading Z.INVSIGCOV
# MT_TF_USArray.CAP02.2010
# reading Z.INVSIGCOV
# MT_TF_USArray.CAP03.2010
# reading Z.INVSIGCOV
# MT_TF_USArray.CAP04.2010
# reading Z.INVSIGCOV
# MT_TF_USArray.CAP05.2010
# reading Z.INVSIGCOV
# MT_TF_USArray.CAQ01.2010
# reading Z.INVSIGCOV
# MT_TF_USArray.CAQ02.2010
# reading Z.INVSIGCOV
# MT_TF_USArray.CAQ03.2010
# reading Z.INVSIGCOV
# MT_TF_USArray.CAQ04.2010
# reading Z.INVSIGCOV
# MT_TF_USArray.CAQ05.2010
# reading Z.INVSIGCOV
# MT_TF_USArray.CAQ06.2010
# reading Z.INVSIGCOV
# MT_TF_USArray.CON20.2011
# reading Z.INVSIGCOV
# MT_TF_USArray.CON21.2011
# reading Z.INVSIGCOV
# MT_TF_USArray.CON24.2018
# reading Z.INVSIGCOV
# MT_TF_USArray.CON25.2018
# reading Z.INVSIGCOV
# MT_TF_USArray.CON26.2018
# reading Z.INVSIGCOV
# MT_TF_USArray.CON27.2018
# reading Z.INVSIGCOV
# MT_TF_USArray.COO20.2011
# reading Z.INVSIGCOV
# MT_TF_USArray.COO21.2011
# reading Z.INVSIGCOV
# MT_TF_USArray.COO22.2018
# reading Z.INVSIGCOV
# MT_TF_USArray.COO24.2018
# reading Z.INVSIGCOV
# MT_TF_USArray.COO25.2018
# reading Z.INVSIGCOV
# MT_TF_USArray.COO26.2018
# reading Z.INVSIGCOV
# MT_TF_USArray.COO27.2018
# reading Z.INVSIGCOV
# MT_TF_USArray.COP20.2011
# reading Z.INVSIGCOV
# MT_TF_USArray.COP21.2011
# reading Z.INVSIGCOV
# MT_TF_USArray.COP22.2018
# reading Z.INVSIGCOV
# MT_TF_USArray.COP24.2018
# reading Z.INVSIGCOV
# MT_TF_USArray.COP25.2018
# reading Z.INVSIGCOV
# MT_TF_USArray.COP26.2018
# reading Z.INVSIGCOV
# MT_TF_USArray.COP27.2018
# reading Z.INVSIGCOV
# MT_TF_USArray.COQ20.2011
# reading Z.INVSIGCOV
# MT_TF_USArray.COQ21.2011
# reading Z.INVSIGCOV
# MT_TF_USArray.COQ23.2018
# reading Z.INVSIGCOV
# MT_TF_USArray.COQ24.2018
# reading Z.INVSIGCOV
# MT_TF_USArray.COQ25.2018
# reading Z.INVSIGCOV
# MT_TF_USArray.COQ27.2018
# reading Z.INVSIGCOV
# MT_TF_USArray.CTI60.2016
# reading Z.INVSIGCOV
# MT_TF_USArray.CTI61.2016
# reading Z.INVSIGCOV
# MT_TF_USArray.DEM59.2016
# reading Z.INVSIGCOV
# MT_TF_USArray
2017
# reading Z.INVSIGCOV
# MT_TF_USArray.TTI57.2017
# reading Z.INVSIGCOV
# MT_TF_USArray.TTJ58.2017
# reading Z.INVSIGCOV
# MT_TF_USArray.TTK58.2016
# reading Z.INVSIGCOV
# MT_TF_USArray.TTL57.2016
# reading Z.INVSIGCOV
# MT_TF_USArray.TTO53.2015
# reading Z.INVSIGCOV
# MT_TF_USArray.TTO58.2016
# reading Z.INVSIGCOV
# MT_TF_USArray.TTS54.2016
# reading Z.INVSIGCOV
# MT_TF_USArray.TTT55.2016
# reading Z.INVSIGCOV
# MT_TF_USArray.TTV52.2016
# reading Z.INVSIGCOV
# MT_TF_USArray.TTV54.2015
# reading Z.INVSIGCOV
# MT_TF_USArray.TTW52.2016
# reading Z.INVSIGCOV
# MT_TF_USArray.TTX52.2015
# reading Z.INVSIGCOV
# MT_TF_USArray.TTY52.2016
# reading Z.INVSIGCOV
# MT_TF_USArray.UTM14.2011
# reading Z.INVSIGCOV
# MT_TF_USArray.UTM15.2011
# reading Z.INVSIGCOV
# MT_TF_USArray.UTM16.2011
# reading Z.INVSIGCOV
# MT_TF_USArray.UTN13.2011
# reading Z.INVSIGCOV
# MT_TF_USArray.UTN14.2011
# reading Z.INVSIGCOV
# MT_TF_USArray.UTN15.2011
# reading Z.INVSIGCOV
# MT_TF_USArray.UTN16.2011
# reading Z.INVSIGCOV
# MT_TF_USArray.UTN17.2011
# reading Z.INVSIGCOV
# MT_TF_USArray.UTN18.2011
# reading Z.INVSIGCOV
# MT_TF_USArray.UTN19.2011
# reading Z.INVSIGCOV
# MT_TF_USArray.UTO13.2011
# reading Z.INVSIGCOV
# MT_TF_USArray.UTO14.2011
# reading Z.INVSIGCOV
# MT_TF_USArray.UTO15.2011
# reading Z.INVSIGCOV
# MT_TF_USArray.UTO16.2011
# reading Z.INVSIGCOV
# skip it! Maximum period is smaller than 1000 sec MT_TF_USArray.UTO16.2011
# MT_TF_USArray.UTO17.2011
# reading Z.INVSIGCOV
# MT_TF_USArray.UTO18.2011
# reading Z.INVSIGCOV
# MT_TF_USArray.UTO19.2011
# reading Z.INVSIGCOV
# MT_TF_USArray.UTP13.2011
# reading Z.INVSIGCOV
# MT_TF_USArray.UTP14.2011
# reading Z.INVSIGCOV
# MT_TF_USArray.UTP15.2011
# reading Z.INVSIGCOV
# MT_TF_USArray.UTP16.2011
# reading Z.INVSIGCOV
# MT_TF_USArray.UTP17.2011
# reading Z.INVSIGCOV
# MT_TF_USArray.UTP18.2011
# reading Z.INVSIGCOV
# MT_TF_USArray.UTP19.2011
# reading Z.INVSIGCOV
# MT_TF_USArray.UTQ13.2011
# reading Z.INVSIGCOV
# MT_TF_USArray.UTQ14.2011
# reading Z.INVSIGCOV
# MT_TF_USArray.UTQ15.2011
# reading Z.INVSIGCOV
# MT_TF_USArray.UTQ16.2011
# reading Z.INVSIGCOV
# MT_TF_USArray.UTQ17.2011
# reading Z.INVSIGCOV
# MT_TF_USArray.UTQ18.2011
# reading Z.INVSIGCOV
# MT_TF_USArray.UTQ19.2011
# reading Z.INVSIGCOV
# MT_TF_USArray.VAO56.2016
# reading Z.INVSIGCOV
# MT_TF_USArray.VAO57.2016
# reading Z.INVSIGCOV
# MT_TF_USArray.VAP55.2016
# reading Z.INVSIGCOV
# MT_TF_USArray.VAP56.2016
# reading Z.INVSIGCOV
# MT_TF_USArray.VAP57.2016
# reading Z.INVSIGCOV
# MT_TF_USArray.VAP58.2016
# reading Z.INVSIGCOV
# MT_TF_USArray.VAP59.2016
# reading Z.INVSIGCOV
# MT_TF_USArray.VAP60.2016
# reading Z.INVSIGCOV
# MT_TF_USArray.VAQ55.2016
# reading Z.INVSIGCOV
# MT_TF_USArray.VAQ56.2016
# reading Z.INVSIGCOV
# MT_TF_USArray.VAQ57.2016
# reading Z.INVSIGCOV
# MT_TF_USArray.VAQ58.2016
# reading Z.INVSIGCOV
# MT_TF_USArray.VAQ59.2016
# reading Z.INVSIGCOV
# MT_TF_USArray.VAQ60.2016
# reading Z.INVSIGCOV
# MT_TF_USArray.VAR54.2016
# reading Z.INVSIGCOV
# MT_TF_USArray.VAR55.2016
# reading Z.INVSIGCOV
# MT_TF_USArray.VAR56.2016
# reading Z.INVSIGCOV
# MT_TF_USArray.VAR57.2016
# reading Z.INVSIGCOV
# MT_TF_USArray.VAR58.2016
# reading Z.INVSIGCOV
# MT_TF_USArray.VAR59.2016
# reading Z.INVSIGCOV
# MT_TF_USArray.VAR60.2016
# reading Z.INVSIGCOV
# MT_TF_USArray.VAS53.2015
# reading Z.INVSIGCOV
# MT_TF_USArray.VAS54.2015
# reading Z.INVSIGCOV
# MT_TF_USArray.VAS55.2016
# reading Z.INVSIGCOV
# MT_TF_USArray.VAS56.2016
# reading Z.INVSIGCOV
# MT_TF_USArray.VTD58.2017
# reading Z.INVSIGCOV
# MT_TF_USArray.VTD59.2017
# reading Z.INVSIGCOV
# MT_TF_USArray.VTE59.2017
# reading Z.INVSIGCOV
# MT_TF_USArray.VTF59.2016
# reading Z.INVSIGCOV
# skip it! Maximum period is smaller than 1000 sec MT_TF_USArray.VTF59.2016
# MT_TF_USArray.VTF60.2017
# reading Z.INVSIGCOV
# MT_TF_USArray.VTG60.2017
# reading Z.INVSIGCOV
# MT_TF_USArray.WAA04.2007
# reading Z.INVSIGCOV
# MT_TF_USArray.WAA05.2007
# reading Z.INVSIGCOV
# MT_TF_USArray.WAA10.2007
# reading Z.INVSIGCOV
# MT_TF_USArray.WAB03.2007
# reading Z.INVSIGCOV
# MT_TF_USArray.WAB04.2007
# reading Z.INVSIGCOV
# MT_TF_USArray.WAB05.2007
# reading Z.INVSIGCOV
# MT_TF_USArray.WAB06.2007
# reading Z.INVSIGCOV
# MT_TF_USArray.WAB07.2007
# reading Z.INVSIGCOV
# MT_TF_USArray.WAB08.2007
# reading Z.INVSIGCOV
# MT_TF_USArray.WAB09.2007
# reading Z.INVSIGCOV
# skip it! Maximum period is smaller than 1000 sec MT_TF_USArray.WAB09.2007
# MT_TF_USArray.WAB10.2007
# reading Z.INVSIGCOV
# MT_TF_USArray.WAC03.2007
# reading Z.INVSIGCOV
# MT_TF_USArray.WAC04.2007
# reading Z.INVSIGCOV
# MT_TF_USArray.WAC05.2007
# reading Z.INVSIGCOV
# MT_TF_USArray.WAC06.2007
# reading Z.INVSIGCOV
# MT_TF_USArray.WAC07.2007
# reading Z.INVSIGCOV
# MT_TF_USArray.WAC08.2007
# reading Z.INVSIGCOV
# MT_TF_USArray.WAC09.2007
# reading Z.INVSIGCOV
# MT_TF_USArray.WAC10.2007
# reading Z.INVSIGCOV
# MT_TF_USArray.WAD03.2007
# reading Z.INVSIGCOV
# MT_TF_USArray.WAD04.2007
# reading Z.INVSIGCOV
# MT_TF_USArray.WAD05.2007
# reading Z.INVSIGCOV
# MT_TF_USArray.WAD06.2007
# reading Z.INVSIGCOV
# MT_TF_USArray.WAD07.2007
# reading Z.INVSIGCOV
# MT_TF_USArray.WAD08.2007
# reading Z.INVSIGCOV
# MT_TF_USArray.WAD09.2007
# reading Z.INVSIGCOV
# MT_TF_USArray.WAD10.2007
# reading Z.INVSIGCOV
# MT_TF_USArray.WAE03.2007
# reading Z.INVSIGCOV
# MT_TF_USArray.WAE04.2007
# reading Z.INVSIGCOV
# MT_TF_USArray.WAE05.2007
# reading Z.INVSIGCOV
# MT_TF_USArray.WAE06.2007
# reading Z.INVSIGCOV
# MT_TF_USArray.WAE07.2007
# reading Z.INVSIGCOV
# MT_TF_USArray.WAE08.2007
# reading Z.INVSIGCOV
# MT_TF_USArray.WAE09.2007
# reading Z.INVSIGCOV
# MT_TF_USArray.WAE10.2007
# reading Z.INVSIGCOV
# MT_TF_USArray.WAF04.2007
# reading Z.INVSIGCOV
# MT_TF_USArray.WAF05.2007
# reading Z.INVSIGCOV
# MT_TF_USArray.WAF06.2007
# reading Z.INVSIGCOV
# MT_TF_USArray.WAF07.2007
# reading Z.INVSIGCOV
# MT_TF_USArray.WID39.2012
# reading Z.INVSIGCOV
# MT_TF_USArray.WIE38.2012
# reading Z.INVSIGCOV
# MT_TF_USArray.WIE39.2011
# reading Z.INVSIGCOV
# MT_TF_USArray.WIF37.2011
# reading Z.INVSIGCOV
# MT_TF_USArray.WIF38.2011
# reading Z.INVSIGCOV
# MT_TF_USArray.WIF39.2011
# reading Z.INVSIGCOV
# MT_TF_USArray.WIF40.2011
# reading Z.INVSIGCOV
# MT_TF_USArray.WIF41.2012
# reading Z.INVSIGCOV
# MT_TF_USArray.WIF42.2012
# reading Z.INVSIGCOV
# MT_TF_USArray.WIG38.2011
# reading Z.INVSIGCOV
# MT_TF_USArray.WIG39.2011
# reading Z.INVSIGCOV
# MT_TF_USArray.WIG40.2011
# reading Z.INVSIGCOV
# MT_TF_USArray.WIG41.2012
# reading Z.INVSIGCOV
# MT_TF_USArray.WIG42.2012
# reading Z.INVSIGCOV
# MT_TF_USArray.WIG43.2012
# reading Z.INVSIGCOV
# MT_TF_USArray.WIH38.2012
# reading Z.INVSIGCOV
# MT_TF_USArray.WIH39.2012
# reading Z.INVSIGCOV
# MT_TF_USArray.WIH40.2012
# reading Z.INVSIGCOV
# MT_TF_USArray.WIH41.2012
# reading Z.INVSIGCOV
# MT_TF_USArray.WIH42.2012
# reading Z.INVSIGCOV
# MT_TF_USArray.WIH43.2012
# reading Z.INVSIGCOV
# MT_TF_USArray.WII40.2011
# reading Z.INVSIGCOV
# MT_TF_USArray.WII41.2012
# reading Z.INVSIGCOV
# MT_TF_USArray.WII42.2012
# reading Z.INVSIGCOV
# MT_TF_USArray.WII43.2012
# reading Z.INVSIGCOV
# MT_TF_USArray.WIJ40.2012
# reading Z.INVSIGCOV
# MT_TF_USArray.WIJ41.2012
# reading Z.INVSIGCOV
# MT_TF_USArray.WIJ42.2012
# reading Z.INVSIGCOV
# MT_TF_USArray.WIJ43.2012
# reading Z.INVSIGCOV
# MT_TF_USArray.WIK41.2012
# reading Z.INVSIGCOV
# MT_TF_USArray.WIK42.2012
# reading Z.INVSIGCOV
# MT_TF_USArray.WVN54.2016
# reading Z.INVSIGCOV
# MT_TF_USArray.WVN56.2016
# reading Z.INVSIGCOV
# MT_TF_USArray.WVO53.2016
# reading Z.INVSIGCOV
# MT_TF_USArray.WVO54.2016
# reading Z.INVSIGCOV
# MT_TF_USArray.WVO55.2016
# reading Z.INVSIGCOV
# MT_TF_USArray.WVP52.2015
# reading Z.INVSIGCOV
# MT_TF_USArray.WVP53.2016
# reading Z.INVSIGCOV
# MT_TF_USArray.WVP54.2016
# reading Z.INVSIGCOV
# MT_TF_USArray.WVQ52.2015
# reading Z.INVSIGCOV
# MT_TF_USArray.WVQ53.2015
# reading Z.INVSIGCOV
# MT_TF_USArray.WVQ54.2016
# reading Z.INVSIGCOV
# MT_TF_USArray.WVR53.2015
# reading Z.INVSIGCOV
# MT_TF_USArray.WYG21.2009
# reading Z.INVSIGCOV
# MT_TF_USArray.WYH18.2009
# reading Z.INVSIGCOV
# MT_TF_USArray.WYH19.2009
# reading Z.INVSIGCOV
# MT_TF_USArray.WYH20.2009
# reading Z.INVSIGCOV
# MT_TF_USArray.WYH21.2009
# reading Z.INVSIGCOV
# MT_TF_USArray.WYH22.2018
# reading Z.INVSIGCOV
# MT_TF_USArray.WYH23.2018
# reading Z.INVSIGCOV
# MT_TF_USArray.WYH24.2018
# reading Z.INVSIGCOV
# MT_TF_USArray.WYI17.2009
# reading Z.INVSIGCOV
# MT_TF_USArray.WYI18.2009
# reading Z.INVSIGCOV
# MT_TF_USArray.WYI19.2009
# reading Z.INVSIGCOV
# MT_TF_USArray.WYI20.2009
# reading Z.INVSIGCOV
# MT_TF_USArray.WYI21.2009
# reading Z.INVSIGCOV
# MT_TF_USArray.WYI22.2018
# reading Z.INVSIGCOV
# MT_TF_USArray.WYI23.2018
# reading Z.INVSIGCOV
# MT_TF_USArray.WYI24.2018
# reading Z.INVSIGCOV
# MT_TF_USArray.WYJ17.2009
# reading Z.INVSIGCOV
# MT_TF_USArray.WYJ18.2009
# reading Z.INVSIGCOV
# MT_TF_USArray.WYJ19.2009
# reading Z.INVSIGCOV
# MT_TF_USArray.WYJ20.2009
# reading Z.INVSIGCOV
# MT_TF_USArray.WYJ21.2009
# reading Z.INVSIGCOV
# MT_TF_USArray.WYJ22.2018
# reading Z.INVSIGCOV
# MT_TF_USArray.WYJ23.2018
# reading Z.INVSIGCOV
# MT_TF_USArray.WYJ24.2018
# reading Z.INVSIGCOV
# MT_TF_USArray.WYK17.2009
# reading Z.INVSIGCOV
# MT_TF_USArray.WYK18.2009
# reading Z.INVSIGCOV
# MT_TF_USArray.WYK19.2009
# reading Z.INVSIGCOV
# MT_TF_USArray.WYK20.2009
# reading Z.INVSIGCOV
# MT_TF_USArray.WYK21.2009
# reading Z.INVSIGCOV
# MT_TF_USArray.WYK22.2018
# reading Z.INVSIGCOV
# MT_TF_USArray.WYK23.2018
# reading Z.INVSIGCOV
# MT_TF_USArray.WYK24.2018
# reading Z.INVSIGCOV
# MT_TF_USArray.WYL17.2009
# reading Z.INVSIGCOV
# MT_TF_USArray.WYL18.2009
# reading Z.INVSIGCOV
# MT_TF_USArray.WYL19.2009
# reading Z.INVSIGCOV
# MT_TF_USArray.WYL20.2009
# reading Z.INVSIGCOV
# MT_TF_USArray.WYL21.2009
# reading Z.INVSIGCOV
# MT_TF_USArray.WYL22.2018
# reading Z.INVSIGCOV
# MT_TF_USArray.WYL23.2018
# reading Z.INVSIGCOV
# MT_TF_USArray.WYL24.2018
# reading Z.INVSIGCOV
# MT_TF_USArray.WYM17.2011
# reading Z.INVSIGCOV
# MT_TF_USArray.WYM18.2011
# reading Z.INVSIGCOV
# MT_TF_USArray.WYM19.2011
# reading Z.INVSIGCOV
# MT_TF_USArray.WYM20.2011
# reading Z.INVSIGCOV
# MT_TF_USArray.WYM21.2011
# reading Z.INVSIGCOV
# MT_TF_USArray.WYM22.2018
# reading Z.INVSIGCOV
# MT_TF_USArray.WYM23.2018
# reading Z.INVSIGCOV
# MT_TF_USArray.WYM24.2018
# reading Z.INVSIGCOV
# MT_TF_USArray.WYM25.2018
# reading Z.INVSIGCOV
# MT_TF_USArray.WYYS1.2009
# reading Z.INVSIGCOV
# MT_TF_USArray.WYYS2.2009
# reading Z.INVSIGCOV
# MT_TF_USArray.WYYS3.2009
# reading Z.INVSIGCOV

# %% [markdown]
# ## data augmentation

# %%
# data augmentation
xml_train, SiteID_train = pyMAGIQ.utils.MAGIQlib.MAGIQlib.dataaug(xml_train, SiteID_train)

# %% [markdown]
# ## convert xml_data to X and y

# %%
# read X (input data) and y (output data: rate) from XML files 
y_train, rate_train, Zapplist, Zapp_errlist, Zphslist, Zphs_errlist = pyMAGIQ.utils.MAGIQlib.MAGIQlib.xml2Z(xml_train,SiteID_train,nfreq,Rotate=True,freq_interp=freqsets)

X_train = pyMAGIQ.utils.MAGIQlib.MAGIQlib.getXfromZ(Zapplist, Zapp_errlist, Zphslist, Zphs_errlist, nfreq, SiteID_train)

# reshape X_train to 2-D array
X_train = X_train.reshape(len(X_train),nfreq*ndata*ncomp*2).astype('float32')

# X (input data) and y (output data: rate) is preprocessed here
# X_train, y_train, rate_train, SiteID_train, xml_train = pyMAGIQ.utils.MAGIQlib.MAGIQlib.getXYdataset(X_train,y_train,nfreq,traindir,trainlists,freqsets)

# change shape to fit it to machine learning
# X_train = X_train.reshape(len(X_train),nfreq*ndata*ncomp*2).astype('float32')

# %% [markdown]
# ## data ordering

# %%
# numofordering=389
numofordering=550
# numofordering=650
X_train_aug = np.zeros((numofordering*5,nfreq*ndata*ncomp*2),dtype=np.float32)
y_train_aug = np.zeros((numofordering*5,),dtype=int)
SiteID_train_aug = []

for irate in range(nrate):
    # index of array having its rate as irate
    itemindex = np.squeeze(np.where(y_train==irate))
    
    # X and y array with irate
    X_irate = X_train[itemindex,:]
    y_irate = y_train[itemindex]
    # SiteID with irate
    SiteID_irate = []
    for j in range(len(itemindex)):
        ii = itemindex[j]
        SiteID_irate.append(SiteID_train[ii])

    # extract numofordering of lines
    idx = np.random.randint(len(y_irate),size=numofordering)
    
    X_irate = X_irate[idx,:]
    y_irate = y_irate[idx]
    SiteID_irate_copy = []
    for j in range(len(idx)):
        ii = idx[j]
        SiteID_irate_copy.append(SiteID_irate[ii])
        
    X_train_aug[irate*numofordering:(irate+1)*numofordering,:] = X_irate
    y_train_aug[irate*numofordering:(irate+1)*numofordering,] = y_irate
    SiteID_train_aug.extend(SiteID_irate_copy.copy())
    
rate_train_aug = y_train_aug + 1

# %% [markdown]
# ## Save data augumentation

# %%
X_trainpath_aug = datadir + '/preprocessed/X_train_aug.csv'
y_trainpath_aug = datadir + '/preprocessed/y_train_aug.csv'
rate_trainpath_aug  = datadir + '/preprocessed/rate_train_aug.csv'
SiteIDpath_aug  = datadir + '/preprocessed/siteID_train_aug.csv'

# save X and y data in csv format. 
np.savetxt( X_trainpath_aug, X_train_aug, delimiter=',')
np.savetxt( y_trainpath_aug, y_train_aug, fmt='%d', delimiter=',')
np.savetxt( rate_trainpath_aug, rate_train_aug, fmt='%d', delimiter=',')

with open(SiteIDpath_aug,'w') as output:
    writer = csv.writer(output, lineterminator='\n')
    for val in SiteID_train_aug:
        writer.writerow([val])

# %% [markdown]
# ## Save training data

# %%
# save X and y data in csv format. 
np.savetxt( X_trainpath, X_train, delimiter=',')
np.savetxt( y_trainpath, y_train, fmt='%d', delimiter=',')
np.savetxt( rate_trainpath, rate_train, fmt='%d', delimiter=',')

with open(SiteIDpath,'w') as output:
    writer = csv.writer(output, lineterminator='\n')
    for val in SiteID_train:
        writer.writerow([val])

# %% [markdown]
# ## histogram of rate

# %%
pyMAGIQ.utils.MAGIQlib.MAGIQlib.ratehistogram1d(rate_train,fname=outputpath+'/rate_hist.eps')

# %%
pyMAGIQ.utils.MAGIQlib.MAGIQlib.ratehistogram1d(rate_train_aug,fname=outputpath+'/rate_hist_aug.eps')

# %% [markdown]
# ## Plot rated Map US

# %%
target='train'

xmin = -140
xmax = -65.0
ymin = 28.0
ymax = 50.0

latlist = []
lonlist = []

# read rate
ratelist = pyMAGIQ.utils.iofiles.io.read_rate_ytrain(y_trainpath)

# read site ID
siteIDlist = pyMAGIQ.utils.iofiles.io.read_siteID(SiteIDpath)

for i in range(len(xml_train)):
    latlist.append(xml_train[i]['lat'])
    lonlist.append(xml_train[i]['lon'])

# latlist,lonlist = read_lonlat(datadir,siteIDlist,target)
fpath = outputpath+'/imageUS.eps'
pyMAGIQ.vis.plotUSmap.plotMap(datadir,xmin,xmax,ymin,ymax,latlist,lonlist,ratelist,fpath)
# Out:
# /Users/nimamura/.pyenv/versions/anaconda3-5.1.0/lib/python3.6/site-packages/mpl_toolkits/basemap/__init__.py:1709: MatplotlibDeprecationWarning: The axesPatch function was deprecated in version 2.1. Use Axes.patch instead.
#   limb = ax.axesPatch
# /Users/nimamura/.pyenv/versions/anaconda3-5.1.0/lib/python3.6/site-packages/mpl_toolkits/basemap/__init__.py:1712: MatplotlibDeprecationWarning: The axesPatch function was deprecated in version 2.1. Use Axes.patch instead.
#   if limb is not ax.axesPatch:

# %% [markdown]
# ## Set unrated data information

# %%
unrateddir       = datadir + '/unrated'
X_unratedpath    = datadir + '/preprocessed/X_unrated.csv'
SiteIDpath_unrated = datadir + '/preprocessed/siteID_unrated.csv'

unratedlists = sorted( [f for f in os.listdir(unrateddir) if not f.startswith('.')] )

nMTunrated  = len(unratedlists)

# %%
Zapplist.shape
# Out:
# (1101, 30, 4)

# %% [markdown]
# ## read unrated data

# %%
# read X_unrated
xml_unrated, SiteID_unrated = pyMAGIQ.utils.iofiles.io.get_XMLlists(nfreq,unrateddir,unratedlists,freqsets,unrated=True)

# read X (input data) and y (output data: rate) from XML files 
Zapplist, Zapp_errlist, Zphslist, Zphs_errlist = pyMAGIQ.utils.MAGIQlib.MAGIQlib.xml2Z(xml_unrated,SiteID_unrated,nfreq,Rotate=True,freq_interp=freqsets,unrated=True)

X_unrated = pyMAGIQ.utils.MAGIQlib.MAGIQlib.getXfromZ(Zapplist, Zapp_errlist, Zphslist, Zphs_errlist, nfreq, SiteID_train)

# reshape X_train to 2-D array
X_unrated = X_unrated.reshape(len(X_unrated),nfreq*ndata*ncomp*2).astype('float32')
# Out:
# MT_TF_CAFE-MT.CAF02.2010
# Use Hx orientation as a declination angle, instead of original declination
# reading Z.INVSIGCOV
# MT_TF_CAFE-MT.CAF04.2010
# Use Hx orientation as a declination angle, instead of original declination
# reading Z.INVSIGCOV
# MT_TF_CAFE-MT.CAF06.2010
# Use Hx orientation as a declination angle, instead of original declination
# reading Z.INVSIGCOV
# MT_TF_CAFE-MT.CAF09.2010
# Use Hx orientation as a declination angle, instead of original declination
# reading Z.INVSIGCOV
# MT_TF_CAFE-MT.CAF11.2010
# Use Hx orientation as a declination angle, instead of original declination
# reading Z.INVSIGCOV
# MT_TF_CAFE-MT.CAF13.2010
# Use Hx orientation as a declination angle, instead of original declination
# reading Z.INVSIGCOV
# skip it! IndexError when reading XML file  MT_TF_CAFE-MT.CAF13.2010
# MT_TF_CAFE-MT.CAF15.2010
# Use Hx orientation as a declination angle, instead of original declination
# reading Z.INVSIGCOV
# MT_TF_CAFE-MT.CAF18.2010
# Use Hx orientation as a declination angle, instead of original declination
# reading Z.INVSIGCOV
# MT_TF_CAFE-MT.CAF20.2010
# Use Hx orientation as a declination angle, instead of original declination
# reading Z.INVSIGCOV
# MT_TF_CAFE-MT.CAF25.2010
# Use Hx orientation as a declination angle, instead of original declination
# reading Z.INVSIGCOV
# MT_TF_CAFE-MT.CAF28.2010
# Use Hx orientation as a declination angle, instead of original declination
# reading Z.INVSIGCOV
# MT_TF_CAFE-MT.CAF32.2010
# Use Hx orientation as a declination angle, instead of original declination
# reading Z.INVSIGCOV
# MT_TF_CAFE-MT.CAF33.2010
# Use Hx orientation as a declination angle, instead of original declination
# reading Z.INVSIGCOV
# MT_TF_CAFE-MT.CAF36.2010
# Use Hx orientation as a declination angle, instead of original declination
# reading Z.INVSIGCOV
# MT_TF_CAFE-MT.CAF40.2010
# Use Hx orientation as a declination angle, instead of original declination
# reading Z.INVSIGCOV
# MT_TF_CAFE-MT.CAF44.2010
# Use Hx orientation as a declination angle, instead of original declination
# reading Z.INVSIGCOV
# MT_TF_CAFE-MT.CAF46.2010
# Use Hx orientation as a declination angle, instead of original declination
# reading Z.INVSIGCOV
# MT_TF_CAFE-MT.CAF48.2010
# Use Hx orientation as a declination angle, instead of original declination
# reading Z.INVSIGCOV
# MT_TF_CAFE-MT.CAF51.2010
# Use Hx orientation as a declination angle, instead of original declination
# reading Z.INVSIGCOV
# MT_TF_CAFE-MT.CAF54.2010
# Use Hx orientation as a declination angle, instead of original declination
# reading Z.INVSIGCOV
# MT_TF_CAFE-MT.CAF58.2010
# Use Hx orientation as a declination angle, instead of original declination
# reading Z.INVSIGCOV
# MT_TF_Lithoprobe.203a.1999
# reading Z.VAR
# skip it! Maximum period is smaller than 1000 sec MT_TF_Lithoprobe.203a.1999
# MT_TF_Lithoprobe.205a.1999
# reading Z.VAR
# skip it! Maximum period is smaller than 1000 sec MT_TF_Lithoprobe.205a.1999
# MT_TF_Lithoprobe.207a.1999
# reading Z.VAR
# skip it! Maximum period is smaller than 1000 sec MT_TF_Lithoprobe.207a.1999
# MT_TF_Lithoprobe.209a.1999
# reading Z.VAR
# skip it! Maximum period is smaller than 1000 sec MT_TF_Lithoprobe.209a.1999
# MT_TF_Lithoprobe.211a.1999
# reading Z.VAR
# skip it! Maximum period is smaller than 1000 sec MT_TF_Lithoprobe.211a.1999
# MT_TF_Lithoprobe.213a.1999
# reading Z.VAR
# skip it! Maximum period is smaller than 1000 sec MT_TF_Lithoprobe.213a.1999
# MT_TF_Lithoprobe.215a.1999
# reading Z.VAR
# skip it! Maximum period is smaller than 1000 sec MT_TF_Lithoprobe.215a.1999
# MT_TF_Lithoprobe.217a.1999
# reading Z.VAR
# skip it! Maximum period is smaller than 1000 sec MT_TF_Lithoprobe.217a.1999
# MT_TF_Lithoprobe.219a.1999
# reading Z.VAR
# skip it! Maximum period is smaller than 1000 sec MT_TF_Lithoprobe.219a.1999
# MT_TF_Lithoprobe.221a.1999
# reading Z.VAR
# skip it! Maximum period is smaller than 1000 sec MT_TF_Lithoprobe.221a.1999
# MT_TF_Lithoprobe.223a.1999
# reading Z.VAR
# skip it! Maximum period is smaller than 1000 sec MT_TF_Lithoprobe.223a.1999
# MT_TF_Lithoprobe.225a.1999
# reading Z.VAR
# skip it! Maximum period is smaller than 1000 sec MT_TF_Lithoprobe.225a.1999
# MT_TF_Lithoprobe.227a.1999
# reading Z.VAR
# skip it! Maximum period is smaller than 1000 sec MT_TF_Lithoprobe.227a.1999
# MT_TF_Lithoprobe.229a.1999
# reading Z.VAR
# skip it! Maximum period is smaller than 1000 sec MT_TF_Lithoprobe.229a.1999
# MT_TF_Lithoprobe.231a.1999
# reading Z.VAR
# skip it! Maximum period is smaller than 1000 sec MT_TF_Lithoprobe.231a.1999
# MT_TF_Lithoprobe.232a.1999
# reading Z.VAR
# skip it! Maximum period is smaller than 1000 sec MT_TF_Lithoprobe.232a.1999
# MT_TF_Lithoprobe.233a.1999
# reading Z.VAR
# skip it! Maximum period is smaller than 1000 sec MT_TF_Lithoprobe.233a.1999
# MT_TF_Lithoprobe.235a.1999
# reading Z.VAR
# skip it! Maximum period is smaller than 1000 sec MT_TF_Lithoprobe.235a.1999
# MT_TF_Lithoprobe.237a.1999
# reading Z.VAR
# skip it! Maximum period is smaller than 1000 sec MT_TF_Lithoprobe.237a.1999
# MT_TF_Lithoprobe.239a.1999
# reading Z.VAR
# skip it! Maximum period is smaller than 1000 sec MT_TF_Lithoprobe.239a.1999
# MT_TF_Lithoprobe.241a.1999
# reading Z.VAR
# skip it! Maximum period is smaller than 1000 sec MT_TF_Lithoprobe.241a.1999
# MT_TF_Lithoprobe.242a.1999
# reading Z.VAR
# skip it! Maximum period is smaller than 1000 sec MT_TF_Lithoprobe.242a.1999
# MT_TF_Lithoprobe.246a.1999
# reading Z.VAR
# skip it! Maximum period is smaller than 1000 sec MT_TF_Lithoprobe.246a.1999
# MT_TF_Lithoprobe.248a.1999
# reading Z.VAR
# skip it! Maximum period is smaller than 1000 sec MT_TF_Lithoprobe.248a.1999
# MT_TF_Lithoprobe.250a.1999
# reading Z.VAR
# skip it! Maximum period is smaller than 1000 sec MT_TF_Lithoprobe.250a.1999
# MT_TF_Lithoprobe.252a.1999
# reading Z.VAR
# skip it! Maximum period is smaller than 1000 sec MT_TF_Lithoprobe.252a.1999
# MT_TF_Lithoprobe.254a.1999
# reading Z.VAR
# skip it! Maximum period is smaller than 1000 sec MT_TF_Lithoprobe.254a.1999
# MT_TF_Lithoprobe.256a.1999
# reading Z.VAR
# skip it! Maximum period is smaller than 1000 sec MT_TF_Lithoprobe.256a.1999
# MT_TF_Lithoprobe.258a.1999
# reading Z.VAR
# skip it! Maximum period is smaller than 1000 sec MT_TF_Lithoprobe.258a.1999
# MT_TF_Lithoprobe.260a.1999
# reading Z.VAR
# skip it! Maximum period is smaller than 1000 sec MT_TF_Lithoprobe.260a.1999
# MT_TF_Lithoprobe.262m.1999
# reading Z.VAR
# skip it! Maximum period is smaller than 1000 sec MT_TF_Lithoprobe.262m.1999
# MT_TF_Lithoprobe.264a.1999
# reading Z.VAR
# skip it! Maximum period is smaller than 1000 sec MT_TF_Lithoprobe.264a.1999
# MT_TF_Lithoprobe.266a.1999
# reading Z.VAR
# skip it! Maximum period is smaller than 1000 sec MT_TF_Lithoprobe.266a.1999
# MT_TF_Lithoprobe.268a.1999
# reading Z.VAR
# skip it! Maximum period is smaller than 1000 sec MT_TF_Lithoprobe.268a.1999
# MT_TF_Lithoprobe.270a.1999
# reading Z.VAR
# skip it! Maximum period is smaller than 1000 sec MT_TF_Lithoprobe.270a.1999
# MT_TF_Lithoprobe.272a.1999
# reading Z.VAR
# skip it! Maximum period is smaller than 1000 sec MT_TF_Lithoprobe.272a.1999
# MT_TF_Lithoprobe.274a.1999
# reading Z.VAR
# skip it! Maximum period is smaller than 1000 sec MT_TF_Lithoprobe.274a.1999
# MT_TF_Lithoprobe.275a.1999
# reading Z.VAR
# skip it! Maximum period is smaller than 1000 sec MT_TF_Lithoprobe.275a.1999
# MT_TF_Lithoprobe.276a.1999
# reading Z.VAR
# skip it! Maximum period is smaller than 1000 sec MT_TF_Lithoprobe.276a.1999
# MT_TF_Lithoprobe.277a.1999
# reading Z.VAR
# skip it! Maximum period is smaller than 1000 sec MT_TF_Lithoprobe.277a.1999
# MT_TF_Lithoprobe.278a.1999
# reading Z.VAR
# skip it! Maximum period is smaller than 1000 sec MT_TF_Lithoprobe.278a.1999
# MT_TF_Lithoprobe.280a.1999
# reading Z.VAR
# skip it! Maximum period is smaller than 1000 sec MT_TF_Lithoprobe.280a.1999
# MT_TF_Lithoprobe.282a.1999
# reading Z.VAR
# skip it! Maximum period is smaller than 1000 sec MT_TF_Lithoprobe.282a.1999
# MT_TF_Lithoprobe.284a.1999
# reading Z.VAR
# skip it! Maximum period is smaller than 1000 sec MT_TF_Lithoprobe.284a.1999
# MT_TF_Lithoprobe.286a.1999
# reading Z.VAR
# skip it! Maximum period is smaller than 1000 sec MT_TF_Lithoprobe.286a.1999
# MT_TF_Lithoprobe.4E00BL.2000
# Use Hx orientation as a declination angle, instead of original declination
# reading Z.VAR
# skip it! Maximum period is smaller than 1000 sec MT_TF_Lithoprobe.4E00BL.2000
# MT_TF_Lithoprobe.4E1000N.2000
# Use Hx orientation as a declination angle, instead of original declination
# reading Z.VAR
# skip it! IndexError when reading XML file  MT_TF_Lithoprobe.4E1000N.2000
# MT_TF_Lithoprobe.4E100N.2000
# Use Hx orientation as a declination angle, instead of original declination
# reading Z.VAR
# skip it! IndexError when reading XML file  MT_TF_Lithoprobe.4E100N.2000
# MT_TF_Lithoprobe.4E175N.2000
# Use Hx orientation as a declination angle, instead of original declination
# reading Z.VAR
# skip it! Maximum period is smaller than 1000 sec MT_TF_Lithoprobe.4E175N.2000
# MT_TF_Lithoprobe.4E200S.2000
# Use Hx orientation as a declination angle, instead of original declination
# reading Z.VAR
# skip it! IndexError when reading XML file  MT_TF_Lithoprobe.4E200S.2000
# MT_TF_Lithoprobe.4E400N.2000
# Use Hx orientation as a declination angle, instead of original declination
# reading Z.VAR
# skip it! Maximum period is smaller than 1000 sec MT_TF_Lithoprobe.4E400N.2000
# MT_TF_Lithoprobe.4E400S.2000
# Use Hx orientation as a declination angle, instead of original declination
# reading Z.VAR
# skip it! IndexError when reading XML file  MT_TF_Lithoprobe.4E400S.2000
# MT_TF_Lithoprobe.4E500N.2000
# Use Hx orientation as a declination angle, instead of original declination
# reading Z.VAR
# skip it! Maximum period is smaller than 1000 sec MT_TF_Lithoprobe.4E500N.2000
# MT_TF_Lithoprobe.4E600N.2000
# Use Hx orientation as a declination angle, instead of original declination
# reading Z.VAR
# skip it! IndexError when reading XML file  MT_TF_Lithoprobe.4E600N.2000
# MT_TF_Lithoprobe.4E825N.2000
# Use Hx orientation as a declination angle, instead of original declination
# reading Z.VAR
# skip it! IndexError when reading XML file  MT_TF_Lithoprobe.4E825N.2000
# MT_TF_Lithoprobe.6e325s.2000
# Use Hx orientation as a declination angle, instead of original declination
# reading Z.VAR
# skip it! IndexError when reading XML file  MT_TF_Lithoprobe.6e325s.2000
# MT_TF_Lithoprobe.ABI-90-001a.1990
# Use Hx orientation as a declination angle, instead of original declination
# reading Z.INVSIGCOV
# skip it! Maximum period is smaller than 1000 sec MT_TF_Lithoprobe.ABI-90-001a.1990
# MT_TF_Lithoprobe.ABI-90-002s.1990
# Use Hx orientation as a declination angle, instead of original declination
# reading Z.INVSIGCOV
# skip it! Maximum period is smaller than 1000 sec MT_TF_Lithoprobe.ABI-90-002s.1990
# MT_TF_Lithoprobe.ABI-90-004a.1990
# Use Hx orientation as a declination angle, instead of original declination
# reading Z.INVSIGCOV
# skip it! Maximum period is smaller than 1000 sec MT_TF_Lithoprobe.ABI-90-004a.1990
# MT_TF_Lithoprobe.ABI-90-005s.1990
# Use Hx orientation as a declination angle, instead of original declination
# reading Z.INVSIGCOV
# skip it! Maximum period is smaller than 1000 sec MT_TF_Lithoprobe.ABI-90-005s.1990
# MT_TF_Lithoprobe.ABI-90-006a.1990
# Use Hx orientation as a declination angle, instead of original declination
# reading Z.INVSIGCOV
# skip it! Maximum period is smaller than 1000 sec MT_TF_Lithoprobe.ABI-90-006a.1990
# MT_TF_Lithoprobe.ABI-90-017a.1990
# Use Hx orientation as a declination angle, instead of original declination
# reading Z.INVSIGCOV
# skip it! Maximum period is smaller than 1000 sec MT_TF_Lithoprobe.ABI-90-017a.1990
# MT_TF_Lithoprobe.ABI-91-003s.1990
# Use Hx orientation as a declination angle, instead of original declination
# reading Z.INVSIGCOV
# skip it! Maximum period is smaller than 1000 sec MT_TF_Lithoprobe.ABI-91-003s.1990
# MT_TF_Lithoprobe.ABI-91-A01s.1991
# Use Hx orientation as a declination angle, instead of original declination
# reading Z.INVSIGCOV
# skip it! Maximum period is smaller than 1000 sec MT_TF_Lithoprobe.ABI-91-A01s.1991
# MT_TF_Lithoprobe.ABI-91-A02s.1991
# Use Hx orientation as a declination angle, instead of original declination
# reading Z.INVSIGCOV
# skip it! Maximum period is smaller than 1000 sec MT_TF_Lithoprobe.ABI-91-A02s.1991
# MT_TF_Lithoprobe.ABI-91-A03s.1991
# Use Hx orientation as a declination angle, instead of original declination
# reading Z.INVSIGCOV
# skip it! Maximum period is smaller than 1000 sec MT_TF_Lithoprobe.ABI-91-A03s.1991
# MT_TF_Lithoprobe.ABI-91-A04s.1991
# Use Hx orientation as a declination angle, instead of original declination
# reading Z.INVSIGCOV
# skip it! Maximum period is smaller than 1000 sec MT_TF_Lithoprobe.ABI-91-A04s.1991
# MT_TF_Lithoprobe.ABI-91-A05s.1991
# Use Hx orientation as a declination angle, instead of original declination
# reading Z.INVSIGCOV
# skip it! Maximum period is smaller than 1000 sec MT_TF_Lithoprobe.ABI-91-A05s.1991
# MT_TF_Lithoprobe.ABI-91-A06s.1991
# Use Hx orientation as a declination angle, instead of original declination
# reading Z.INVSIGCOV
# skip it! Maximum period is smaller than 1000 sec MT_TF_Lithoprobe.ABI-91-A06s.1991
# MT_TF_Lithoprobe.ABI-91-A07s.1991
# Use Hx orientation as a declination angle, instead of original declination
# reading Z.INVSIGCOV
# skip it! Maximum period is smaller than 1000 sec MT_TF_Lithoprobe.ABI-91-A07s.1991
# MT_TF_Lithoprobe.ABI-91-A08s.1991
# Use Hx orientation as a declination angle, instead of original declination
# reading Z.INVSIGCOV
# skip it! Maximum period is smaller than 1000 sec MT_TF_Lithoprobe.ABI-91-A08s.1991
# MT_TF_Lithoprobe.ABI-91-A09s.1991
# Use Hx orientation as a declination angle, instead of original declination
# reading Z.INVSIGCOV
# skip it! Maximum period is smaller than 1000 sec MT_TF_Lithoprobe.ABI-91-A09s.1991
# MT_TF_Lithoprobe.ABI-91-A10s.1991
# Use Hx orientation as a declination angle, instead of original declination
# reading Z.INVSIGCOV
# skip it! Maximum period is smaller than 1000 sec MT_TF_Lithoprobe.ABI-91-A10s.1991
# MT_TF_Lithoprobe.ABI-91-A11s.1991
# Use Hx orientation as a declination angle, instead of original declination
# reading Z.INVSIGCOV
# skip it! Maximum period is smaller than 1000 sec MT_TF_Lithoprobe.ABI-91-A11s.1991
# MT_TF_Lithoprobe.ABI-91-A12s.1991
# Use Hx orientation as a declination angle, instead of original declination
# reading Z.INVSIGCOV
# skip it! Maximum period is smaller than 1000 sec MT_TF_Lithoprobe.ABI-91-A12s.1991
# MT_TF_Lithoprobe.ABI-91-A13s.1991
# Use Hx orientation as a declination angle, instead of original declination
# reading Z.INVSIGCOV
# skip it! Maximum period is smaller than 1000 sec MT_TF_Lithoprobe.ABI-91-A13s.1991
# MT_TF_Lithoprobe.ABI-91-A14s.1991
# Use Hx orientation as a declination angle, instead of original declination
# reading Z.INVSIGCOV
# skip it! Maximum period is smaller than 1000 sec MT_TF_Lithoprobe.ABI-91-A14s.1991
# MT_TF_Lithoprobe.ABI-91-A15s.1991
# Use Hx orientation as a declination angle, instead of original declination
# reading Z.INVSIGCOV
# skip it! Maximum period is smaller than 1000 sec MT_TF_Lithoprobe.ABI-91-A15s.1991
# MT_TF_Lithoprobe.ABI-91-A16s.1991
# Use Hx orientation as a declination angle, instead of original declination
# reading Z.INVSIGCOV
# skip it! Maximum period is smaller than 1000 sec MT_TF_Lithoprobe.ABI-91-A16s.1991
# MT_TF_Lithoprobe.ABI-91-A17s.1991
# Use Hx orientation as a declination angle, instead of original declination
# reading Z.INVSIGCOV
# skip it! Maximum period is smaller than 1000 sec MT_TF_Lithoprobe.ABI-91-A17s.1991
# MT_TF_Lithoprobe.ABI-91-A18s.1991
# Use Hx orientation as a declination angle, instead of original declination
# reading Z.INVSIGCOV
# skip it! Maximum period is smaller than 1000 sec MT_TF_Lithoprobe.ABI-91-A18s.1991
# MT_TF_Lithoprobe.ABI-91-A19s.1991
# Use Hx orientation as a declination angle, instead of original declination
# reading Z.INVSIGCOV
# skip it! Maximum period is smaller than 1000 sec MT_TF_Lithoprobe.ABI-91-
.1987
# Use Hx orientation as a declination angle, instead of original declination
# reading Z.INVSIGCOV
# skip it! Maximum period is smaller than 1000 sec MT_TF_Lithoprobe.EMR-007a.1987
# MT_TF_Lithoprobe.EMR-008a.1987
# Use Hx orientation as a declination angle, instead of original declination
# reading Z.INVSIGCOV
# skip it! Maximum period is smaller than 1000 sec MT_TF_Lithoprobe.EMR-008a.1987
# ...
# MT_TF_Lithoprobe.tho-m53s.1992
# Use Hx orientation as a declination angle, instead of original declination
# reading Z.INVSIGCOV
# skip it! Maximum period is smaller than 1000 sec MT_TF_Lithoprobe.tho-m53s.1992
# MT_TF_Lithoprobe.tho-m54s.1992
# Use Hx orientation as a declination angle, instead of original declination
# reading Z.INVSIGCOV
# skip it! Maximum period is smaller than 1000 sec MT_TF_Lithoprobe.tho-m54s.1992
# MT_TF_Lithoprobe.tho-m55s.1992
# Use Hx orientation as a declination angle, instead of original declination
# reading Z.INVSIGCOV
# skip it! Maximum period is smaller than 1000 sec MT_TF_Lithoprobe.tho-m55s.1992
# MT_TF_Lithoprobe.tho-m56s.1992
# Use Hx orientation as a declination angle, instead of original declination
# reading Z.INVSIGCOV
# skip it! Maximum period is smaller than 1000 sec MT_TF_Lithoprobe.tho-m56s.1992
# MT_TF_Lithoprobe.wlb001.1984
# Use Hx orientation as a declination angle, instead of original declination
# reading Z.INVSIGCOV
# skip it! Maximum period is smaller than 1000 sec MT_TF_Lithoprobe.wlb001.1984
# MT_TF_Lithoprobe.wlb003.1984
# Use Hx orientation as a declination angle, instead of original declination
# reading Z.INVSIGCOV
# skip it! Maximum period is smaller than 1000 sec MT_TF_Lithoprobe.wlb003.1984
# MT_TF_Lithoprobe.wlb004.1984
# Use Hx orientation as a declination angle, instead of original declination
# reading Z.INVSIGCOV
# skip it! Maximum period is smaller than 1000 sec MT_TF_Lithoprobe.wlb004.1984
# MT_TF_Lithoprobe.wlb005.1984
# Use Hx orientation as a declination angle, instead of original declination
# reading Z.INVSIGCOV
# skip it! Maximum period is smaller than 1000 sec MT_TF_Lithoprobe.wlb005.1984
# MT_TF_Lithoprobe.wlb006.1984
# Use Hx orientation as a declination angle, instead of original declination
# reading Z.INVSIGCOV
# skip it! Maximum period is smaller than 1000 sec MT_TF_Lithoprobe.wlb006.1984
# MT_TF_Lithoprobe.wlb007.1984
# Use Hx orientation as a declination angle, instead of original declination
# reading Z.INVSIGCOV
# skip it! Maximum period is smaller than 1000 sec MT_TF_Lithoprobe.wlb007.1984
# MT_TF_Lithoprobe.wlb008.1984
# Use Hx orientation as a declination angle, instead of original declination
# reading Z.INVSIGCOV
# skip it! Maximum period is smaller than 1000 sec MT_TF_Lithoprobe.wlb008.1984
# MT_TF_Lithoprobe.wlb009.1984
# Use Hx orientation as a declination angle, instead of original declination
# reading Z.INVSIGCOV
# skip it! Maximum period is smaller than 1000 sec MT_TF_Lithoprobe.wlb009.1984
# MT_TF_Lithoprobe.wlb010.1984
# Use Hx orientation as a declination angle, instead of original declination
# reading Z.INVSIGCOV
# skip it! Maximum period is smaller than 1000 sec MT_TF_Lithoprobe.wlb010.1984
# MT_TF_Lithoprobe.wlb012.1984
# Use Hx orientation as a declination angle, instead of original declination
# reading Z.INVSIGCOV
# skip it! Maximum period is smaller than 1000 sec MT_TF_Lithoprobe.wlb012.1984
# MT_TF_Lithoprobe.wlb013.1984
# Use Hx orientation as a declination angle, instead of original declination
# reading Z.INVSIGCOV
# skip it! Maximum period is smaller than 1000 sec MT_TF_Lithoprobe.wlb013.1984
# MT_TF_Lithoprobe.wlb014.1984
# Use Hx orientation as a declination angle, instead of original declination
# reading Z.INVSIGCOV
# skip it! Maximum period is smaller than 1000 sec MT_TF_Lithoprobe.wlb014.1984
# MT_TF_Lithoprobe.wlb015.1984
# Use Hx orientation as a declination angle, instead of original declination
# reading Z.INVSIGCOV
# skip it! Maximum period is smaller than 1000 sec MT_TF_Lithoprobe.wlb015.1984
# MT_TF_Lithoprobe.wst01.2000
# Use Hx orientation as a declination angle, instead of original declination
# reading Z.INVSIGCOV
# skip it! Maximum period is smaller than 1000 sec MT_TF_Lithoprobe.wst01.2000
# MT_TF_Lithoprobe.wst02.2000
# Use Hx orientation as a declination angle, instead of original declination
# reading Z.INVSIGCOV
# skip it! Maximum period is smaller than 1000 sec MT_TF_Lithoprobe.wst02.2000
# MT_TF_Lithoprobe.wst03.2000
# Use Hx orientation as a declination angle, instead of original declination
# reading Z.INVSIGCOV
# skip it! Maximum period is smaller than 1000 sec MT_TF_Lithoprobe.wst03.2000
# MT_TF_Lithoprobe.wst04.2000
# Use Hx orientation as a declination angle, instead of original declination
# reading Z.INVSIGCOV
# skip it! Maximum period is smaller than 1000 sec MT_TF_Lithoprobe.wst04.2000
# MT_TF_Lithoprobe.wst05.2000
# Use Hx orientation as a declination angle, instead of original declination
# reading Z.INVSIGCOV
# skip it! Maximum period is smaller than 1000 sec MT_TF_Lithoprobe.wst05.2000
# MT_TF_Lithoprobe.wst06c.2000
# Use Hx orientation as a declination angle, instead of original declination
# reading Z.INVSIGCOV
# skip it! Maximum period is smaller than 1000 sec MT_TF_Lithoprobe.wst06c.2000
# MT_TF_Lithoprobe.wst07c.2000
# Use Hx orientation as a declination angle, instead of original declination
# reading Z.INVSIGCOV
# skip it! Maximum period is smaller than 1000 sec MT_TF_Lithoprobe.wst07c.2000
# MT_TF_Lithoprobe.wst08.2000
# Use Hx orientation as a declination angle, instead of original declination
# reading Z.INVSIGCOV
# skip it! Maximum period is smaller than 1000 sec MT_TF_Lithoprobe.wst08.2000
# MT_TF_Lithoprobe.wst09.2000
# Use Hx orientation as a declination angle, instead of original declination
# reading Z.INVSIGCOV
# skip it! Maximum period is smaller than 1000 sec MT_TF_Lithoprobe.wst09.2000
# MT_TF_Lithoprobe.wst10.2000
# Use Hx orientation as a declination angle, instead of original declination
# reading Z.INVSIGCOV
# skip it! Maximum period is smaller than 1000 sec MT_TF_Lithoprobe.wst10.2000
# MT_TF_Lithoprobe.wst11.2000
# Use Hx orientation as a declination angle, instead of original declination
# reading Z.INVSIGCOV
# skip it! Maximum period is smaller than 1000 sec MT_TF_Lithoprobe.wst11.2000
# MT_TF_Lithoprobe.wst12.2000
# Use Hx orientation as a declination angle, instead of original declination
# reading Z.INVSIGCOV
# skip it! Maximum period is smaller than 1000 sec MT_TF_Lithoprobe.wst12.2000
# MT_TF_Lithoprobe.wst13.2000
# Use Hx orientation as a declination angle, instead of original declination
# reading Z.INVSIGCOV
# skip it! Maximum period is smaller than 1000 sec MT_TF_Lithoprobe.wst13.2000
# MT_TF_Lithoprobe.wst14.2000
# Use Hx orientation as a declination angle, instead of original declination
# reading Z.INVSIGCOV
# skip it! Maximum period is smaller than 1000 sec MT_TF_Lithoprobe.wst14.2000
# MT_TF_Lithoprobe.wst15.2000
# Use Hx orientation as a declination angle, instead of original declination
# reading Z.INVSIGCOV
# skip it! Maximum period is smaller than 1000 sec MT_TF_Lithoprobe.wst15.2000
# MT_TF_Lithoprobe.wst16.2000
# Use Hx orientation as a declination angle, instead of original declination
# reading Z.INVSIGCOV
# skip it! Maximum period is smaller than 1000 sec MT_TF_Lithoprobe.wst16.2000
# MT_TF_Lithoprobe.wst17.2000
# Use Hx orientation as a declination angle, instead of original declination
# reading Z.INVSIGCOV
# skip it! Maximum period is smaller than 1000 sec MT_TF_Lithoprobe.wst17.2000
# MT_TF_Lithoprobe.wst18.2000
# Use Hx orientation as a declination angle, instead of original declination
# reading Z.INVSIGCOV
# skip it! Maximum period is smaller than 1000 sec MT_TF_Lithoprobe.wst18.2000
# MT_TF_Lithoprobe.wst19.2000
# Use Hx orientation as a declination angle, instead of original declination
# reading Z.INVSIGCOV
# skip it! Maximum period is smaller than 1000 sec MT_TF_Lithoprobe.wst19.2000
# MT_TF_Lithoprobe.wst20.2000
# Use Hx orientation as a declination angle, instead of original declination
# reading Z.INVSIGCOV
# skip it! Maximum period is smaller than 1000 sec MT_TF_Lithoprobe.wst20.2000
# MT_TF_Lithoprobe.wst21.2000
# Use Hx orientation as a declination angle, instead of original declination
# reading Z.INVSIGCOV
# skip it! Maximum period is smaller than 1000 sec MT_TF_Lithoprobe.wst21.2000
# MT_TF_Lithoprobe.wst23.2000
# Use Hx orientation as a declination angle, instead of original declination
# reading Z.INVSIGCOV
# skip it! Maximum period is smaller than 1000 sec MT_TF_Lithoprobe.wst23.2000
# MT_TF_Lithoprobe.wst24.2000
# Use Hx orientation as a declination angle, instead of original declination
# reading Z.INVSIGCOV
# skip it! Maximum period is smaller than 1000 sec MT_TF_Lithoprobe.wst24.2000
# MT_TF_Lithoprobe.wst25.2000
# Use Hx orientation as a declination angle, instead of original declination
# reading Z.INVSIGCOV
# skip it! Maximum period is smaller than 1000 sec MT_TF_Lithoprobe.wst25.2000
# MT_TF_Lithoprobe.wst26.2000
# Use Hx orientation as a declination angle, instead of original declination
# reading Z.INVSIGCOV
# skip it! Maximum period is smaller than 1000 sec MT_TF_Lithoprobe.wst26.2000
# MT_TF_Lithoprobe.wst29.2000
# Use Hx orientation as a declination angle, instead of original declination
# reading Z.INVSIGCOV
# skip it! Maximum period is smaller than 1000 sec MT_TF_Lithoprobe.wst29.2000
# MT_TF_Lithoprobe.wst30.2000
# Use Hx orientation as a declination angle, instead of original declination
# reading Z.INVSIGCOV
# skip it! Maximum period is smaller than 1000 sec MT_TF_Lithoprobe.wst30.2000
# MT_TF_Lithoprobe.wst31.2000
# Use Hx orientation as a declination angle, instead of original declination
# reading Z.INVSIGCOV
# skip it! Maximum period is smaller than 1000 sec MT_TF_Lithoprobe.wst31.2000
# MT_TF_Lithoprobe.wst32.2000
# Use Hx orientation as a declination angle, instead of original declination
# reading Z.INVSIGCOV
# skip it! Maximum period is smaller than 1000 sec MT_TF_Lithoprobe.wst32.2000
# MT_TF_Lithoprobe.wst33.2000
# Use Hx orientation as a declination angle, instead of original declination
# reading Z.INVSIGCOV
# skip it! Maximum period is smaller than 1000 sec MT_TF_Lithoprobe.wst33.2000
# MT_TF_Lithoprobe.wst34.2000
# Use Hx orientation as a declination angle, instead of original declination
# reading Z.INVSIGCOV
# skip it! Maximum period is smaller than 1000 sec MT_TF_Lithoprobe.wst34.2000
# MT_TF_Lithoprobe.wst35.2000
# Use Hx orientation as a declination angle, instead of original declination
# reading Z.INVSIGCOV
# skip it! Maximum period is smaller than 1000 sec MT_TF_Lithoprobe.wst35.2000
# MT_TF_Lithoprobe.wst36.2000
# Use Hx orientation as a declination angle, instead of original declination
# reading Z.INVSIGCOV
# skip it! Maximum period is smaller than 1000 sec MT_TF_Lithoprobe.wst36.2000
# MT_TF_UofAlberta.ab715.2010
# reading Z.VAR
# MT_TF_UofAlberta.ab716.2010
# reading Z.VAR
# MT_TF_UofAlberta.ab717.2010
# reading Z.VAR
# MT_TF_UofAlberta.ab718.2010
# reading Z.VAR
# MT_TF_UofAlberta.ab814.2010
# Use Hx orientation as a declination angle, instead of original declination
# reading Z.VAR
# MT_TF_UofAlberta.ab914.2010
# Use Hx orientation as a declination angle, instead of original declination
# reading Z.VAR
# MT_TF_UofAlberta.ab915.2010
# reading Z.VAR
# MT_TF_UofAlberta.ab916.2010
# reading Z.VAR
# MT_TF_UofAlberta.aba114.2008
# reading Z.VAR
# MT_TF_UofAlberta.aba115.2008
# reading Z.VAR
# MT_TF_UofAlberta.aba116.2008
# reading Z.VAR
# MT_TF_UofAlberta.aba117.2008
# reading Z.VAR
# MT_TF_UofAlberta.aba213.2008
# reading Z.VAR
# MT_TF_UofAlberta.aba313.2008
# reading Z.VAR
# MT_TF_UofAlberta.aba314.2008
# reading Z.VAR
# MT_TF_UofAlberta.aba315.2008
# reading Z.VAR
# MT_TF_UofAlberta.aba316.2008
# reading Z.VAR
# MT_TF_UofAlberta.aba317.2008
# reading Z.VAR
# MT_TF_UofAlberta.aba415.2008
# reading Z.VAR
# MT_TF_UofAlberta.aba513.2008
# reading Z.VAR
# MT_TF_UofAlberta.aba613.2008
# reading Z.VAR
# MT_TF_UofAlberta.aba614.2008
# reading Z.VAR
# MT_TF_UofAlberta.aba713.2008
# reading Z.VAR
# MT_TF_UofAlberta.aba714.2008
# reading Z.VAR
# skip it! IndexError when reading XML file  MT_TF_UofAlberta.aba714.2008
# MT_TF_UofAlberta.aba813.2008
# reading Z.VAR
# MT_TF_UofAlberta.bc009.2009
# reading Z.VAR
# MT_TF_UofAlberta.bc010.2009
# reading Z.VAR
# MT_TF_UofAlberta.bc109.2009
# reading Z.VAR
# MT_TF_UofAlberta.bc110.2009
# reading Z.VAR
# MT_TF_UofAlberta.bc210.2009
# reading Z.VAR
# MT_TF_UofAlberta.bc309.2009
# reading Z.VAR
# MT_TF_UofAlberta.bc310.2009
# reading Z.VAR
# MT_TF_UofAlberta.bc409.2009
# reading Z.VAR
# MT_TF_UofAlberta.bc410.2009
# reading Z.VAR
# MT_TF_UofAlberta.rc010RR060.2008
# Use Hx orientation as a declination angle, instead of original declination
# reading Z.VAR
# MT_TF_UofAlberta.rc020RR060.2008
# Use Hx orientation as a declination angle, instead of original declination
# reading Z.VAR
# MT_TF_UofAlberta.rc030RR070.2008
# Use Hx orientation as a declination angle, instead of original declination
# reading Z.VAR
# MT_TF_UofAlberta.rc040RR070.2008
# Use Hx orientation as a declination angle, instead of original declination
# reading Z.VAR
# MT_TF_UofAlberta.rc050RR070.2008
# Use Hx orientation as a declination angle, instead of original declination
# reading Z.VAR
# MT_TF_UofAlberta.rc060RR070.2008
# Use Hx orientation as a declination angle, instead of original declination
# reading Z.VAR
# MT_TF_UofAlberta.rc065RR070.2008
# Use Hx orientation as a declination angle, instead of original declination
# reading Z.VAR
# MT_TF_UofAlberta.rc070RR120.2008
# Use Hx orientation as a declination angle, instead of original declination
# reading Z.VAR
# MT_TF_UofAlberta.rc075RR070.2008
# Use Hx orientation as a declination angle, instead of original declination
# reading Z.VAR
# MT_TF_UofAlberta.rc080RR070.2008
# Use Hx orientation as a declination angle, instead of original declination
# reading Z.VAR
# MT_TF_UofAlberta.rc085RR070.2008
# Use Hx orientation as a declination angle, instead of original declination
# reading Z.VAR
# MT_TF_UofAlberta.rc090RR110.2008
# Use Hx orientation as a declination angle, instead of original declination
# reading Z.VAR
# MT_TF_UofAlberta.rc095RR120.2008
# Use Hx orientation as a declination angle, instead of original declination
# reading Z.VAR
# MT_TF_UofAlberta.rc100RR120.2008
# Use Hx orientation as a declination angle, instead of original declination
# reading Z.VAR
# MT_TF_UofAlberta.rc110RR070.2008
# Use Hx orientation as a declination angle, instead of original declination
# reading Z.VAR
# MT_TF_UofAlberta.rc120RR070.2008
# Use Hx orientation as a declination angle, instead of original declination
# reading Z.VAR
# MT_TF_UofAlberta.sa001.2009
# reading Z.VAR
# MT_TF_UofAlberta.sa005.2009
# reading Z.VAR
# MT_TF_UofAlberta.sa010.2009
# reading Z.VAR
# MT_TF_UofAlberta.sa015.2009
# reading Z.VAR
# MT_TF_UofAlberta.sa020.2009
# reading Z.VAR
# MT_TF_UofAlberta.sa025.2009
# reading Z.VAR
# skip it! IndexError when reading XML file  MT_TF_UofAlberta.sa025.2009
# MT_TF_UofAlberta.sa030.2009
# reading Z.VAR
# MT_TF_UofAlberta.sa035.2009
# reading Z.VAR
# MT_TF_UofAlberta.sa040.2009
# reading Z.VAR
# MT_TF_UofAlberta.sa045.2009
# reading Z.VAR
# MT_TF_UofAlberta.sa050.2009
# reading Z.VAR
# skip it! IndexError when reading XML file  MT_TF_UofAlberta.sa050.2009
# MT_TF_UofAlberta.sa055.2009
# reading Z.VAR
# MT_TF_UofAlberta.sa060.2009
# reading Z.VAR
# skip it! IndexError when reading XML file  MT_TF_UofAlberta.sa060.2009
# MT_TF_UofAlberta.sa065.2009
# reading Z.VAR
# MT_TF_UofAlberta.sa070.2009
# reading Z.VAR
# MT_TF_UofAlberta.sa075.2009
# reading Z.VAR
# MT_TF_UofAlberta.sa080.2009
# reading Z.VAR
# MT_TF_UofAlberta.sa085.2009
# reading Z.VAR
# MT_TF_UofAlberta.sa090.2009
# reading Z.VAR
# MT_TF_UofAlberta.sa095.2009
# reading Z.VAR
# MT_TF_UofAlberta.sa100.2009
# reading Z.VAR
# MT_TF_UofAlberta.sa105.2009
# reading Z.VAR
# MT_TF_UofAlberta.sa110.2009
# reading Z.VAR
# MT_TF_UofAlberta.sa115.2009
# reading Z.VAR
# MT_TF_UofAlberta.sa117.2009
# reading Z.VAR
# MT_TF_UofAlberta.sa120.2009
# reading Z.VAR
# MT_TF_UofAlberta.sa125.2009
# reading Z.VAR
# MT_TF_UofAlberta.sa130.2009
# reading Z.VAR
# MT_TF_UofAlberta.sa140.2009
# reading Z.VAR
# MT_TF_UofAlberta.sa145.2009
# reading Z.VAR
# MT_TF_UofAlberta.sa150.2009
# reading Z.VAR
# MT_TF_UofAlberta.sa155.2009
# reading Z.VAR
# MT_TF_UofAlberta.sa160.2009
# reading Z.VAR
# MT_TF_UofAlberta.sa165.2009
# reading Z.VAR
# MT_TF_UofAlberta.sa170.2009
# reading Z.VAR
# MT_TF_UofAlberta.sa175.2010
# reading Z.VAR
# MT_TF_UofAlberta.sa180.2010
# reading Z.VAR
# MT_TF_UofAlberta.sa185.2010
# reading Z.VAR
# MT_TF_UofAlberta.sa190.2010
# reading Z.VAR
# MT_TF_UofAlberta.sa195.2010
# reading Z.VAR
# MT_TF_UofAlberta.sa200.2009
# reading Z.VAR
# MT_TF_UofAlberta.sa204.2010
# reading Z.VAR
# MT_TF_UofAlberta.sa210.2009
# reading Z.VAR
# MT_TF_UofAlberta.sa215.2009
# reading Z.VAR
# MT_TF_UofAlberta.sa220.2009
# reading Z.VAR
# MT_TF_UofAlberta.sa225.2009
# reading Z.VAR
# MT_TF_UofAlberta.sa230.2010
# reading Z.VAR
# MT_TF_UofAlberta.sa235.2010
# reading Z.VAR
# MT_TF_UofAlberta.sa240.2010
# reading Z.VAR
# MT_TF_UofAlberta.sa245.2010
# reading Z.VAR

# %%
# # # read X_unrated
# # X_unrated = np.zeros((nMTunrated,nfreq,ndata*ncomp*2),dtype=np.float32)    # Note that real value
# # X_unrated,SiteID_unrated, xml_unrated = pyMAGIQ.utils.MAGIQlib.MAGIQlib.getX_unrated(X_unrated,nfreq,unrateddir,unratedlists,freqsets)

# # # convert shape
# # X_unrated = X_unrated.reshape(len(X_unrated),nfreq*ndata*ncomp*2).astype('float32')

# # set y_vote for voting
# # y_vote = np.zeros( (len(X_unrated),nrate), dtype=np.float )

# # save X and y data in csv format. You don't have to read EDI files again
# np.savetxt( X_unratedpath,  X_unrated, delimiter=',')
# with open(SiteIDpath_unrated,'w') as output:
#     writer = csv.writer(output, lineterminator='\n')
#     for val in SiteID_unrated:
#         writer.writerow([val])

# %% [markdown]
# ## save unrated data

# %%
# save X and y data in csv format. 
np.savetxt( X_unratedpath, X_unrated, delimiter=',')

with open(SiteIDpath_unrated,'w') as output:
    writer = csv.writer(output, lineterminator='\n')
    for val in SiteID_unrated:
        writer.writerow([val])

# save xml_unrated dict with pickle
try:
    import cPickle as pickle
except ImportError:  # python 3.x
    import pickle
    
with open(outputpath+'/xml_unrated.p', 'wb') as fp:
    pickle.dump(xml_unrated, fp, protocol=pickle.HIGHEST_PROTOCOL)
